# %%
import os
from getpass import getpass

token = getpass("Введите ваш GitHub токен: ")  # ввод скрыт
username = "AnNyiiik"
repo = "Explainable_logical_fallacies_classification_in_Russian_texts"

os.environ["GITHUB_TOKEN"] = token
# !git clone https://{username}:{token}@github.com/{username}/{repo}.git
# Out:
# Введите ваш GitHub токен: ··········
# Cloning into 'Explainable_logical_fallacies_classification_in_Russian_texts'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (170/170), done.
# remote: Total 248 (delta 114), reused 205 (delta 74), pack-reused 0 (from 0)
# Receiving objects: 100% (248/248), 5.16 MiB | 18.08 MiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %%
# %cd /content/Explainable_logical_fallacies_classification_in_Russian_texts/
# !pip install -r requirements.txt
# Out:
# /content/Explainable_logical_fallacies_classification_in_Russian_texts
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 425.6/425.6 kB 41.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 kB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 608.4/608.4 kB 57.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires requests==2.32.4, but you have requests 2.34.2 which is incompatible.
# ...

# %%
# %cd /content/Explainable_logical_fallacies_classification_in_Russian_texts
# !bash code/experiments/launch_scripts/eval.sh
# Out:
# /content/Explainable_logical_fallacies_classification_in_Russian_texts
# + MODEL=deepvk/USER-bge-m3
# + DATA_DIR=./data/multiclass_TACEI_data
# + INPUT_FILE=./data/multiclass_TACEI_data/train_ru.tsv
# + N_FOLDS=5
# + SEEDS='12345 67891 54321 999 777'
# + N_EPOCHS=5
# + PATIENCE=3
# + LR=2e-5
# + EXP_WEIGHT=0.2
# + TRAIN_BATCH_SIZE=4
# + TEST_BATCH_SIZE=32
# + MAX_LEN=512
# + CLS_HIDDEN_SIZE=128
# + EXP_HIDDEN_SIZE=128
# + ACCUMULATION_STEPS=2
# + export WANDB_MODE=disabled
# + WANDB_MODE=disabled
# + mkdir -p results
# + for SEED in $SEEDS
# + echo =========================================
# ...
# + echo 'Running cross-validation with seed=12345'
# Running cross-validation with seed=12345
# + echo =========================================
# ...
